# %%
import pandas as pd
import functions as f
import pandas as pd
import numpy as np
import requests
from PIL import Image
from io import BytesIO

# %%
df_rating = pd.read_csv('data/Books_rating.csv')
df_book = pd.read_csv('data/books_data.csv')

# %%
## Exploremos nuestros datasets

# %%
f.explorar_df(df_rating)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  object
#  1   Title               object
#  2   Price               float64
#  3   User_id             object
#  4   profileName         object
#  5   review/helpfulness  object
#  6   review/score        float64
#  7   review/time         int64
#  8   review/summary      object
#  9   review/text         object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 228.9+ MB
# None
# Primeras filas
#            Id                           Title  Price         User_id  \
# 0  1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1  0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2  0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3  0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# ...

# %%
f.explorar_df(df_book)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212404 entries, 0 to 212403
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Title          212403 non-null  object
#  1   description    143962 non-null  object
#  2   authors        180991 non-null  object
#  3   image          160329 non-null  object
#  4   previewLink    188568 non-null  object
#  5   publisher      136518 non-null  object
#  6   publishedDate  187099 non-null  object
#  7   infoLink       188568 non-null  object
#  8   categories     171205 non-null  object
#  9   ratingsCount   49752 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 16.2+ MB
# None
# Primeras filas
#                                                Title  \
# 0                     Its Only Art If Its Well Hung!
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# ...

# %%
## Dado la cantidad de nulos y duplicados, tomamos la decisión de directamente eliminar ambos, sobre todo por la cantidad de registros que hay. Es decir, elegimos eliminarlos también como manera de tener un df más pequeño para procesarlo.

# %%
rating = f.limpiar_dataset(df_rating)

# %%
book = f.limpiar_dataset(df_book)

# %%
## Veamos un poco más a fondo los datasets y comprobamos si se ha efectuado la limpieza

# %%
f.explorar_df(rating)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 414018 entries, 10 to 2999988
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  414018 non-null  object
#  1   title               414018 non-null  object
#  2   price               414018 non-null  float64
#  3   user_id             414018 non-null  object
#  4   profilename         414018 non-null  object
#  5   review/helpfulness  414018 non-null  object
#  6   review/score        414018 non-null  float64
#  7   review/time         414018 non-null  int64
#  8   review/summary      414018 non-null  object
#  9   review/text         414018 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 34.7+ MB
# None
# Primeras filas
#             id                                  title  price         user_id  \
# 10  0829814000  Wonderful Worship in Smaller Churches  19.40   AZ0IOBU20TBOP
# ...

# %%
f.explorar_df(book)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40635 entries, 5 to 212402
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          40635 non-null  object
#  1   description    40635 non-null  object
#  2   authors        40635 non-null  object
#  3   image          40635 non-null  object
#  4   previewlink    40635 non-null  object
#  5   publisher      40635 non-null  object
#  6   publisheddate  40635 non-null  object
#  7   infolink       40635 non-null  object
#  8   categories     40635 non-null  object
#  9   ratingscount   40635 non-null  float64
# dtypes: float64(1), object(9)
# memory usage: 3.4+ MB
# None
# Primeras filas
#                                                 title  \
# 5   The Church of Christ: A Biblical Ecclesiology ...
# 31  Voices from the Farm: Adventures in Community ...
# 33                            The Battleship Bismarck
# ...

# %%
rating.columns
# Out:
# Index(['id', 'title', 'price', 'user_id', 'profilename', 'review/helpfulness',
#        'review/score', 'review/time', 'review/summary', 'review/text'],
#       dtype='object')

# %%
rating.rename(columns ={'profilename':'profile_name'}, inplace=True)

# %%
book.columns
# Out:
# Index(['title', 'description', 'authors', 'image', 'previewlink', 'publisher',
#        'publisheddate', 'infolink', 'categories', 'ratingscount'],
#       dtype='object')

# %%
book.rename(columns ={'previewlink':'preview_link',
                      'publisheddate':'published_date',
                      'infolink':'info_link',
                      'ratingscount': 'ratings_count'}, inplace=True)

# %%
## Eliminamos columnas que no vamos a utilizar 
book = book.drop(['preview_link', 'info_link'], axis=1)

# %%
rating.nunique()
# Out:
# id                     47981
# title                  47364
# price                   5926
# user_id               305427
# profile_name          273129
# review/helpfulness      5819
# review/score               5
# review/time             5685
# review/summary        325608
# review/text           396233
# dtype: int64

# %%
book.nunique()
# Out:
# title             40635
# description       36616
# authors           26809
# image             36907
# publisher          4660
# published_date     6891
# categories         1105
# ratings_count       454
# dtype: int64

# %%
book.shape
# Out:
# (40635, 8)

# %%
book['published_date'].head()
# Out:
# 5           1996
# 31    2012-08-21
# 33    2018-09-20
# 42       2002-11
# 43          2005
# Name: published_date, dtype: object

# %% [markdown]
# # Creación de nuevas columnas

# %%
## Aplicamos una función para que, de las portadas de los libros, nos añada una columna con el color rgb principal de las portadas.

# %%
# TARDA CASI TRES HORAS
# book['color_rgb'] = book['image'].apply(f.obtener_color_dominante)

# %%
book.columns
# Out:
# Index(['title', 'description', 'authors', 'image', 'publisher',
#        'published_date', 'categories', 'ratings_count'],
#       dtype='object')

# %%
## Como el procesos anterior tarda tanto, decidimos guardar el df para trabajar de ahora en adelante con estos cambios ya aplicados. 
# book.to_csv('df_temporal.csv', index=False)
# rating.to_csv('rating_temporal.csv', index=False)
